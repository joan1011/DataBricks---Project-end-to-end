# %% [markdown]
# # Reading from CSV File

# %%
df = spark.read.option("header", "true").option("inferSchema", "true").csv("/Volumes/workspace/bronze/source_systems/source_crm/cust_info.csv")
df.display()

# %% [markdown]
# # Write it to Bronze Layer as a table for crm_cust_info

# %%
df.write.mode("overwrite").saveAsTable("workspace.bronze.crm_cust_info")

# %%
# %sql
SELECT *
FROM workspace.bronze.crm_cust_info LIMIT 100

# %%
files = dbutils.fs.ls("/Volumes/workspace/bronze/source_systems/source_crm/")
display(files)

# %% [markdown]
# # Reading and Writing product and Sales Information for CRM

# %%
df = spark.read.option("header", "true").option("inferSchema", "true").csv("/Volumes/workspace/bronze/source_systems/source_crm/prd_info.csv")
df.display()
df.write.mode("overwrite").saveAsTable("workspace.bronze.crm_prd_info")
df = spark.read.option("header", "true").option("inferSchema", "true").csv("/Volumes/workspace/bronze/source_systems/source_crm/sales_details.csv")
df.display()
df.write.mode("overwrite").saveAsTable("workspace.bronze.crm_sales_info")

# %%
files = dbutils.fs.ls("/Volumes/workspace/bronze/source_systems/source_erp/")
display(files)

# %% [markdown]
# # Loading ERP data into Bronze tables

# %%
df = spark.read.option("header", "true").option("inferSchema", "true").csv('/Volumes/workspace/bronze/source_systems/source_erp/CUST_AZ12.csv', header=True)
df.write.mode("overwrite").saveAsTable("workspace.bronze.erp_cust_az12")
df = spark.read.option("header", "true").option("inferSchema", "true").csv('/Volumes/workspace/bronze/source_systems/source_erp/LOC_A101.csv', header=True)
df.write.mode("overwrite").saveAsTable("workspace.bronze.erp_loc_a101")
df = spark.read.option("header", "true").option("inferSchema", "true").csv('/Volumes/workspace/bronze/source_systems/source_erp/PX_CAT_G1V2.csv', header=True)
df.write.mode("overwrite").saveAsTable("workspace.bronze.erp_px_cat_g1v2")
